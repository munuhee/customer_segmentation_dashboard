# %% [markdown]
# **Data Loading and Preprocessing**:

# %%
import pandas as pd
df = pd.read_csv('../data/customer_data_clustered.csv')
df.head()
# Out:
#    CustomerID  Frequency  TotalSpend   Recency  Cluster
# 0     12346.0  -0.329608   -0.239419  1.867222        0
# 1     12347.0   0.206214    0.287803  0.364960        0
# 2     12348.0  -0.115280    0.262708  1.640838        0
# 3     12349.0  -0.436773   -0.104075 -1.520356        1
# 4     12350.0  -0.436773   -0.197164  1.690671        0

# %% [markdown]
# **Exploratory Data Analysis**:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Distribution of Total Spend
sns.histplot(df['TotalSpend'])
plt.title('Distribution of Total Spend')
plt.show()

# Pairplot
sns.pairplot(df[['TotalSpend', 'Frequency', 'Recency', 'Cluster']], hue='Cluster')
plt.title('Pairplot of Features by Cluster')
plt.show()

# %% [markdown]
# **Cluster Analysis**:

# %%
# Analysis of clusters
cluster_summary = df.groupby('Cluster').mean()
print(cluster_summary)
# Out:
#            CustomerID  Frequency  TotalSpend   Recency
# Cluster
# 0        15295.998645   0.091740    0.000109  0.796040
# 1        15306.451265  -0.192163   -0.104715 -0.827457
# 2        15135.500000   9.061886    8.244877  0.149947
# 3        14646.000000   7.600554   41.831767  0.061495

# %% [markdown]
# **Insights**:

# %% [markdown]
# - **Cluster 0** has the highest average spend.
# - **Cluster 1** includes customers with the highest recency.
